# %% [markdown]
# # Integração de Pandas com Great Expectations e Polars
# Este notebook demonstra como utilizar as bibliotecas **Pandas**, **Great Expectations** e **Polars** juntas.

# %% [markdown]
# ## 1. Validação de Dados com Great Expectations e Pandas

# %%
import pandas as pd
import great_expectations as ge

# Criar um DataFrame com pandas
df = ge.get_context({
    'nome': ['Alice', 'Bob', None],
    'idade': [25, 30, 35]
})

df.head()



# Converter para um DataFrame do Great Expectations
# df = ge.from_pandas(df)

# Validar que a coluna 'nome' não possui valores nulos
df.expect_column_values_to_not_be_null(column='nome')

# Resultado da validação
print("Resultado da validação para 'nome':", expectation['success'])

# Validar que a coluna 'idade' está entre 20 e 40
expectation = df.expect_column_values_to_be_between(
    column='idade', min_value=20, max_value=40
)
print("Resultado da validação para 'idade':", expectation['success'])
# Out:
# Error while processing DataContextConfig: no config_version key
# ---------------------------------------------------------------------------
# InvalidDataContextConfigError             Traceback (most recent call last)
# Cell In[15], line 5
#       2 import great_expectations as ge
#       4 # Criar um DataFrame com pandas
# ----> 5 df = ge.get_context({
#       6     'nome': ['Alice', 'Bob', None],
#       7     'idade': [25, 30, 35]
#       8 })
#      10 df.head()
#      14 # Converter para um DataFrame do Great Expectations
#      15 # df = ge.from_pandas(df)
#      16
#      17 # Validar que a coluna 'nome' não possui valores nulos
#
# File ~/Repos/gabrielcruzg3/college/college/.venv/lib/python3.12/site-packages/great_expectations/data_context/data_context/context_factory.py:535, in get_context(project_config, context_root_dir, project_root_dir, runtime_environment, cloud_base_url, cloud_access_token, cloud_organization_id, cloud_mode, mode)
#     452 @public_api
#     453 def get_context(  # noqa: PLR0913
#     454     project_config: DataContextConfig | Mapping | None = None,
#    (...)
#     462     mode: ContextModes | None = None,
#     463 ) -> AbstractDataContext:
#     464     """Method to return the appropriate Data Context depending on parameters and environment.
#     465
#     466     Usage:
#    (...)
#     533         GXCloudConfigurationError: Cloud mode enabled, but missing configuration.
#     534     """  # noqa: E501
# --> 535     return project_manager.get_project(
#     536         project_config=project_config,
#     537         context_root_dir=context_root_dir,
#     538         project_root_dir=project_root_dir,
#     539         runtime_environment=runtime_environment,
#     540         cloud_base_url=cloud_base_url,
#     541         cloud_access_token=cloud_access_token,
#     542         cloud_organization_id=cloud_organization_id,
#     543         cloud_mode=cloud_mode,
#     544         mode=mode,
#     545     )
#
# File ~/Repos/gabrielcruzg3/college/college/.venv/lib/python3.12/site-packages/great_expectations/data_context/data_context/context_factory.py:74, in ProjectManager.get_project(self, project_config, context_root_dir, project_root_dir, runtime_environment, cloud_base_url, cloud_access_token, cloud_organization_id, cloud_mode, mode)
#      62 def get_project(  # noqa: PLR0913
#      63     self,
#      64     project_config: DataContextConfig | Mapping | None = None,
#    (...)
#      72     mode: ContextModes | None = None,
#      73 ) -> AbstractDataContext:
# ---> 74     self.__project = self._build_context(
#      75         project_config=project_config,
#      76         context_root_dir=context_root_dir,
#      77         project_root_dir=project_root_dir,
#      78         runtime_environment=runtime_environment,
#      79         cloud_base_url=cloud_base_url,
#      80         cloud_access_token=cloud_access_token,
#      81         cloud_organization_id=cloud_organization_id,
#      82         cloud_mode=cloud_mode,
#      83         mode=mode,
#      84     )
#      85     return self.__project
#
# File ~/Repos/gabrielcruzg3/college/college/.venv/lib/python3.12/site-packages/great_expectations/data_context/data_context/context_factory.py:162, in ProjectManager._build_context(self, project_config, context_root_dir, project_root_dir, runtime_environment, cloud_base_url, cloud_access_token, cloud_organization_id, cloud_mode, mode)
#     150 def _build_context(  # noqa: PLR0913
#     151     self,
#     152     project_config: DataContextConfig | Mapping | None = None,
#    (...)
#     160     mode: ContextModes | None = None,
#     161 ) -> AbstractDataContext:
# --> 162     project_config = self._prepare_project_config(project_config)
#     164     param_lookup: dict[ContextModes | None, dict] = {
#     165         "ephemeral": dict(
#     166             project_config=project_config,
#    (...)
#     193         ),
#     194     }
#     195     try:
#
# File ~/Repos/gabrielcruzg3/college/college/.venv/lib/python3.12/site-packages/great_expectations/data_context/data_context/context_factory.py:292, in ProjectManager._prepare_project_config(self, project_config)
#     290 # If available and applicable, convert project_config mapping into a rich config type
#     291 if project_config:
# --> 292     project_config = AbstractDataContext.get_or_create_data_context_config(project_config)
#     293 assert project_config is None or isinstance(
#     294     project_config, DataContextConfig
#     295 ), "project_config must be of type Optional[DataContextConfig]"
#     297 return project_config
#
# File ~/Repos/gabrielcruzg3/college/college/.venv/lib/python3.12/site-packages/great_expectations/data_context/data_context/abstract_data_context.py:1853, in AbstractDataContext.get_or_create_data_context_config(cls, project_config)
#    1851 # Roundtrip through schema validation to remove any illegal fields add/or restore any missing fields.  # noqa: E501
#    1852 project_config_dict = dataContextConfigSchema.dump(project_config)
# -> 1853 project_config_dict = dataContextConfigSchema.load(project_config_dict)
#    1854 context_config: DataContextConfig = DataContextConfig(**project_config_dict)
#    1855 return context_config
#
# File ~/Repos/gabrielcruzg3/college/college/.venv/lib/python3.12/site-packages/marshmallow/schema.py:722, in Schema.load(self, data, many, partial, unknown)
#     691 def load(
#     692     self,
#     693     data: (
#    (...)
#     700     unknown: str | None = None,
#     701 ):
#     702     """Deserialize a data structure to an object defined by this Schema's fields.
#     703
#     704     :param data: The data to deserialize.
#    (...)
#     720         if invalid data are passed.
#     721     """
# --> 722     return self._do_load(
#     723         data, many=many, partial=partial, unknown=unknown, postprocess=True
#     724     )
#
# File ~/Repos/gabrielcruzg3/college/college/.venv/lib/python3.12/site-packages/marshmallow/schema.py:908, in Schema._do_load(self, data, many, partial, unknown, postprocess)
#     906 if errors:
#     907     exc = ValidationError(errors, data=data, valid_data=result)
# --> 908     self.handle_error(exc, data, many=many, partial=partial)
#     909     raise exc
#     911 return result
#
# File ~/Repos/gabrielcruzg3/college/college/.venv/lib/python3.12/site-packages/great_expectations/data_context/types/base.py:1145, in DataContextConfigSchema.handle_error(self, exc, data, **kwargs)
#    1143 message: str = f"Error while processing DataContextConfig: {' '.join(exc.messages)}"
#    1144 logger.error(message)
# -> 1145 raise gx_exceptions.InvalidDataContextConfigError(
#    1146     message=message,
#    1147 )
#
# InvalidDataContextConfigError: Error while processing DataContextConfig: no config_version key

# %% [markdown]
# ## 2. Manipulação de Dados com Polars e Pandas

# %%
import polars as pl

# Criar um DataFrame com pandas
df_pandas = pd.DataFrame({
    'nome': ['Alice', 'Bob', 'Charlie'],
    'idade': [25, 30, 35]
})

# Converter para Polars
df_polars = pl.from_pandas(df_pandas)

# Filtrar dados com Polars
df_polars_filtered = df_polars.filter(pl.col('idade') > 30)
print("DataFrame filtrado com Polars:")
print(df_polars_filtered)

# Converter de volta para Pandas
df_pandas_final = df_polars_filtered.to_pandas()
print("DataFrame convertido de volta para Pandas:")
print(df_pandas_final)
# Out:
# DataFrame filtrado com Polars:
# shape: (1, 2)
# ┌─────────┬───────┐
# │ nome    ┆ idade │
# │ ---     ┆ ---   │
# │ str     ┆ i64   │
# ╞═════════╪═══════╡
# │ Charlie ┆ 35    │
# └─────────┴───────┘
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_62152/681010997.py in ?()
#      14 print("DataFrame filtrado com Polars:")
#      15 print(df_polars_filtered)
#      16
#      17 # Converter de volta para Pandas
# ---> 18 df_pandas_final = df_polars_filtered.to_pandas()
#      19 print("DataFrame convertido de volta para Pandas:")
#      20 print(df_pandas_final)
#
# ~/Repos/gabrielcruzg3/college/college/.venv/lib/python3.12/site-packages/polars/dataframe/frame.py in ?(self, use_pyarrow_extension_array, **kwargs)
#    2408             return self._to_pandas_with_object_columns(
#    2409                 use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    2410             )
#    2411
# -> 2412         return self._to_pandas_without_object_columns(
#    2413             self, use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    2414         )
#
# ~/Repos/gabrielcruzg3/college/college/.venv/lib/python3.12/site-packages/polars/dataframe/frame.py in ?(self, df, use_pyarrow_extension_array, **kwargs)
#    2459     ) -> pd.DataFrame:
#    2460         if not df.width:  # Empty dataframe, cannot infer schema from batches
#    2461             return pd.DataFrame()
#    2462
# -> 2463         record_batches = df._df.to_pandas()
#    2464         tbl = pa.Table.from_batches(record_batches)
#    2465         if use_pyarrow_extension_array:
#    2466             return tbl.to_pandas(
#
# ModuleNotFoundError: No module named 'pyarrow'

# %% [markdown]
# ## 3. Integração entre Polars e Great Expectations via Pandas

# %%
# Converter um DataFrame de Polars para Pandas
df_pandas_from_polars = df_polars.to_pandas()

# Validar com Great Expectations
df = ge.from_pandas(df_pandas_from_polars)
expectation = df.expect_column_to_exist('nome')
print("A coluna 'nome' existe no DataFrame:", expectation['success'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_62152/599391517.py in ?()
#       1 # Converter um DataFrame de Polars para Pandas
# ----> 2 df_pandas_from_polars = df_polars.to_pandas()
#       3
#       4 # Validar com Great Expectations
#       5 df = ge.from_pandas(df_pandas_from_polars)
#
# ~/Repos/gabrielcruzg3/college/college/.venv/lib/python3.12/site-packages/polars/dataframe/frame.py in ?(self, use_pyarrow_extension_array, **kwargs)
#    2408             return self._to_pandas_with_object_columns(
#    2409                 use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    2410             )
#    2411
# -> 2412         return self._to_pandas_without_object_columns(
#    2413             self, use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    2414         )
#
# ~/Repos/gabrielcruzg3/college/college/.venv/lib/python3.12/site-packages/polars/dataframe/frame.py in ?(self, df, use_pyarrow_extension_array, **kwargs)
#    2459     ) -> pd.DataFrame:
#    2460         if not df.width:  # Empty dataframe, cannot infer schema from batches
#    2461             return pd.DataFrame()
#    2462
# -> 2463         record_batches = df._df.to_pandas()
#    2464         tbl = pa.Table.from_batches(record_batches)
#    2465         if use_pyarrow_extension_array:
#    2466             return tbl.to_pandas(
#
# ModuleNotFoundError: No module named 'pyarrow'
